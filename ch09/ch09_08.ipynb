# %%
### LlamParse로 파싱하기

# %%
# !uv add dotenv
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# !uv add llama-index-core llama-parse llama-index-readers-file

# %%
import os
import nest_asyncio

nest_asyncio.apply()

# %%
from llama_parse import LlamaParse
from llama_index.core import SimpleDirectoryReader
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1904\1977201079.py:1: DeprecationWarning: The 'llama-parse' package is deprecated and will no longer receive updates. Please migrate to the new unified SDK. See https://developers.llamaindex.ai/python/cloud/llamaparse/getting_started/ and https://github.com/run-llama/llama-cloud-py/blob/main/README.md for migration instructions.
#   from llama_parse import LlamaParse

# %%
# 파서 설정
parser = LlamaParse(
    result_type="markdown",  # "markdown"과 "text" 사용 가능
    num_workers=8,  # worker 수 (기본값: 4)
    verbose=True,
    language="ko",
)

# SimpleDirectoryReader를 사용하여 파일 파싱
file_extractor = {".pdf": parser}

# LlamaParse로 파일 파싱
documents = SimpleDirectoryReader(
    input_files=["../data/SPRI_AI_Brief_2023년12월호_F.pdf"],
    file_extractor=file_extractor,
).load_data()
# Out:
# 2026-09-21 12:40:34,631 - INFO - HTTP Request: POST https://api.cloud.llamaindex.ai/api/parsing/upload "HTTP/1.1 200 OK"
# Started parsing the file under job_id e26f1df2-d44f-4b31-9921-4f6d5c3587f1
# 2026-09-21 12:40:35,912 - INFO - HTTP Request: GET https://api.cloud.llamaindex.ai/api/parsing/job/e26f1df2-d44f-4b31-9921-4f6d5c3587f1 "HTTP/1.1 200 OK"
# 2026-09-21 12:40:38,172 - INFO - HTTP Request: GET https://api.cloud.llamaindex.ai/api/parsing/job/e26f1df2-d44f-4b31-9921-4f6d5c3587f1 "HTTP/1.1 200 OK"
# 2026-09-21 12:40:41,418 - INFO - HTTP Request: GET https://api.cloud.llamaindex.ai/api/parsing/job/e26f1df2-d44f-4b31-9921-4f6d5c3587f1 "HTTP/1.1 200 OK"
# 2026-09-21 12:40:45,660 - INFO - HTTP Request: GET https://api.cloud.llamaindex.ai/api/parsing/job/e26f1df2-d44f-4b31-9921-4f6d5c3587f1 "HTTP/1.1 200 OK"
# 2026-09-21 12:40:51,624 - INFO - HTTP Request: GET https://api.cloud.llamaindex.ai/api/parsing/job/e26f1df2-d44f-4b31-9921-4f6d5c3587f1 "HTTP/1.1 200 OK"
# 2026-09-21 12:40:57,321 - INFO - HTTP Request: GET https://api.cloud.llamaindex.ai/api/parsing/job/e26f1df2-d44f-4b31-9921-4f6d5c3587f1 "HTTP/1.1 200 OK"
# 2026-09-21 12:41:03,032 - INFO - HTTP Request: GET https://api.cloud.llamaindex.ai/api/parsing/job/e26f1df2-d44f-4b31-9921-4f6d5c3587f1 "HTTP/1.1 200 OK"
# 2026-09-21 12:41:08,684 - INFO - HTTP Request: GET https://api.cloud.llamaindex.ai/api/parsing/job/e26f1df2-d44f-4b31-9921-4f6d5c3587f1 "HTTP/1.1 200 OK"
# 2026-09-21 12:41:13,961 - INFO - HTTP Request: GET https://api.cloud.llamaindex.ai/api/parsing/job/e26f1df2-d44f-4b31-9921-4f6d5c3587f1 "HTTP/1.1 200 OK"
# 2026-09-21 12:41:19,209 - INFO - HTTP Request: GET https://api.cloud.llamaindex.ai/api/parsing/job/e26f1df2-d44f-4b31-9921-4f6d5c3587f1 "HTTP/1.1 200 OK"
# .
# 2026-09-21 12:41:24,877 - INFO - HTTP Request: GET https://api.cloud.llamaindex.ai/api/parsing/job/e26f1df2-d44f-4b31-9921-4f6d5c3587f1 "HTTP/1.1 200 OK"
# 2026-09-21 12:41:25,581 - INFO - HTTP Request: GET https://api.cloud.llamaindex.ai/api/parsing/job/e26f1df2-d44f-4b31-9921-4f6d5c3587f1/result/markdown "HTTP/1.1 200 OK"

# %%
len(documents)
# Out:
# 23

# %%
documents[0]
# Out:
# Document(id_='5595ed22-3e8b-4f72-809d-79605ffdec09', embedding=None, metadata={'file_path': '..\\data\\SPRI_AI_Brief_2023년12월호_F.pdf', 'file_name': 'SPRI_AI_Brief_2023년12월호_F.pdf', 'file_type': 'application/pdf', 'file_size': 975735, 'creation_date': '2026-09-21', 'last_modified_date': '2026-09-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='\n\n# SPRI AI Brief\n\n인공지능 산업의 최신 동향\n\n**2023년 12월호**\n\n----\n\nSPRI 소프트웨어정책연구소  \nSoftware Policy & Research Institute\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')

# %% [markdown]
# ### 멀티모달 모델을 파싱하기
